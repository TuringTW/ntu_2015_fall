# %%
#Problem 1
# Numerically solve u"(x)-(x**2-K)*u(x)=0
#ans 
#1st state K = 1
#2nd state K = 3
#3rd state K = 5
#4th state K = 7
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt 
# %matplotlib inline
from IPython.html.widgets import interact, interactive
from IPython.html import widgets
from IPython.display import display, Math, Latex
from __future__ import division
from sympy import *
import sympy.plotting as splt
import matplotlib.pyplot as plt

init_printing(use_latex='mathjax')

# Python does not have the nice NDSolve command as in Mathematica, but we can still do it
# First, split the 2nd-order ODE into two coupled first-order ODEs
# y0'=y1 
# y1'=(x**2-K)*y0


# specify the x points where we want the solution
x_pts=np.arange(0,5,0.01) # generates a series from 0 to 5(not included) with step size 0.01

# enter interactive session

def plot_sol(K):
    K=float(K)
    # define the RHS of the two ODEs and store as a vector
    def f(y,x):
        return [y[1],(x**2-K)*y[0]]
    
    # initial conditions for [y0(0),y1(0)]
    ics=[1,0]
    
    # solve the coupled ODEs numerically
    sol=odeint(f,ics,x_pts)
  
    # plot the solution
    fig=plt.figure(figsize=(12,8))
    ax=fig.add_subplot(111)
    ax.set_xlabel("$x$",fontsize=18)
    ax.set_ylabel("$\psi(x)$",fontsize=18)
    ax.set_title('Numeircal Solution',fontsize=18) 
    ax.set_ylim([-1,2])
    ax.plot(x_pts,sol[:,0],lw=2,color='g')
    ax.axhline(linewidth=1, color='blue')

    plt.show()

    
i=interact(plot_sol,K=1)

# %%
#Problem 2
# Numerically solve u"(x)-(-K**2)*u(x)=0
#ans 
#1st state K = 1*pi = 3.14159
#2nd state K = 2*pi = 6.28318
#3rd state K = 3*pi = 9.42477
#4th state K = 4*pi = 12.5663
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt 
# %matplotlib inline
from IPython.html.widgets import interact, interactive
from IPython.html import widgets
from IPython.display import display, Math, Latex
from __future__ import division
from sympy import *
import sympy.plotting as splt
import matplotlib.pyplot as plt

init_printing(use_latex='mathjax')

# Python does not have the nice NDSolve command as in Mathematica, but we can still do it
# First, split the 2nd-order ODE into two coupled first-order ODEs
# y0'=y1 
# y1'=(x**2-K)*y0


# specify the x points where we want the solution
x_pts=np.arange(0,5,0.01) # generates a series from 0 to 5(not included) with step size 0.01

# enter interactive session

def plot_sol(K):
    K=float(K)
    # define the RHS of the two ODEs and store as a vector
    def f(y,x):
        return [y[1],(-K**2)*y[0]]
    
    # initial conditions for [y0(0),y1(0)]
    ics=[0,1]
    
    # solve the coupled ODEs numerically
    sol=odeint(f,ics,x_pts)
  
    # plot the solution
    fig=plt.figure(figsize=(12,8))
    ax=fig.add_subplot(111)
    ax.set_xlabel("$x$",fontsize=18)
    ax.set_ylabel("$\psi(x)$",fontsize=18)
    ax.set_title('Numeircal Solution',fontsize=18) 
    ax.set_ylim([-1,2])
    ax.plot(x_pts,sol[:,0],lw=2,color='g')
    ax.axhline(linewidth=1, color='blue')

    plt.show()
def calc_sol(K):
    K=float(K)
    # define the RHS of the two ODEs and store as a vector
    def f(y,x):
        return [y[1],(-K**2)*y[0]]
    
    # initial conditions for [y0(0),y1(0)]
    ics=[0,1]
    
    # solve the coupled ODEs numerically
    sol=odeint(f,ics,x_pts)
    return sol[100,0]



    
i=interact(plot_sol,K=np.pi)

y_pts=np.arange(0,10,0.001)
d = 0.0005
for ii in range(0, len(y_pts)):
    if (calc_sol(y_pts[ii])-0)<d and (calc_sol(y_pts[ii])-0)>-d:
        print(y_pts[ii])
# Out:
# 3.141
# 3.142
# 3.143
# 6.281
# 6.282
# 6.283
# 6.284
# 6.285
# 6.286
# 9.421
# 9.422
# 9.423
# 9.424
# 9.425
# 9.426
# 9.427
# 9.428
# 9.429

# %%
#Problem 3
# Numerically solve u"(x)-(x**2-K)*u(x)=0
#ans
#ground state     K = 1.065285504
#1st exited state K = 3.30687201
#2ns exited state K = 5.74795925
#3rd exited state K = 8.3526778

import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt 
# %matplotlib inline
from IPython.html.widgets import interact, interactive
from IPython.html import widgets
from IPython.display import display, Math, Latex
from __future__ import division
from sympy import *
import sympy.plotting as splt
import matplotlib.pyplot as plt

init_printing(use_latex='mathjax')

# Python does not have the nice NDSolve command as in Mathematica, but we can still do it
# First, split the 2nd-order ODE into two coupled first-order ODEs
# y0'=y1 
# y1'=(x**2-K)*y0


# specify the x points where we want the solution
x_pts=np.arange(0,5,0.01) # generates a series from 0 to 5(not included) with step size 0.01

# enter interactive session

def plot_sol(K):
    K=float(K)
    # define the RHS of the two ODEs and store as a vector
    def f(y,x):
        return [y[1],(x**2+(x**4)/10-K)*y[0]]
    
    # initial conditions for [y0(0),y1(0)]
    ics=[0,1]
    
    # solve the coupled ODEs numerically
    sol=odeint(f,ics,x_pts)
  
    # plot the solution
    fig=plt.figure(figsize=(12,8))
    ax=fig.add_subplot(111)
    ax.set_xlabel("$x$",fontsize=18)
    ax.set_ylabel("$\psi(x)$",fontsize=18)
    ax.set_title('Numeircal Solution',fontsize=18) 
    ax.set_ylim([-1,2])
    ax.plot(x_pts,sol[:,0],lw=2,color='g')
    ax.axhline(linewidth=1, color='blue')

    plt.show()
    
i=interact(plot_sol,K=8.3526778)
